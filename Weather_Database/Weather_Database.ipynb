# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# importing sys
import sys
  
# adding parent directory to the system path so the config.py is accessible
sys.path.insert(0, '../')

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90, high = 90, size = 2000)
lngs = np.random.uniform(low = -180, high = 180, size = 2000)
lat_lngs = zip(lats, lngs)

#lat_lngs

# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
coordinates[:5]
# Out:
# [(83.85880040289206, 166.2607241313553),
#  (-49.84964298354914, -15.508901144840678),
#  (19.38855908120047, 20.478267426556727),
#  (82.93677709152493, -117.13261938846748),
#  (-51.0543497926503, 64.29009504490111)]

# %%
# Import Citipy
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []

## Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 725

# %%
# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the neginning of the logging.
print( "Beginning Data Retrieval      ")
print("-------------------------------")

# Create counters
record_count = 1
set_count = 1

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -------------------------------

# %%
# Loop through all the cities in the list
for i, city in enumerate(cities):
    
    # Group cities in sets of 60 for logging purposes
    # Wait to complete one minute to request the next 60 group (60 requests/minute in the free package)
    if (i % 60 == 0):
        if (i >= 60):
            set_count += 1
            record_count = 1
            print(time.time() - start_sleep)
            time.sleep(time.time() - start_sleep)
            start_sleep = time.time()
        else:
            start_sleep = time.time()
        
    # Create endpoint URL with each city
    city_url = url + "&appid=" + weather_api_key + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        
        city_curr_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Country': city_country,
                          'Current Description': city_curr_description})
        
    # If an error is experienced, skip the city.
    except:
        print('City not found. Skipping...')
        pass
    
# Indicate that Data loading is complete
print('---------------------------------')
print('Data Retrieval Complete          ')
print('---------------------------------')
# Out:
# Processing Record 1 of Set 1 | pevek
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | faya
# Processing Record 4 of Set 1 | norman wells
# Processing Record 5 of Set 1 | saint-philippe
# Processing Record 6 of Set 1 | khonsa
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | severo-kurilsk
# Processing Record 9 of Set 1 | ponazyrevo
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | paamiut
# Processing Record 12 of Set 1 | luderitz
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | arraial do cabo
# Processing Record 16 of Set 1 | khasan
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | chuy
# Processing Record 20 of Set 1 | upernavik
# Processing Record 21 of Set 1 | qaanaaq
# Processing Record 22 of Set 1 | sao francisco
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | makarov
# Processing Record 25 of Set 1 | serebryansk
# Processing Record 26 of Set 1 | bayan
# Processing Record 27 of Set 1 | faanui
# Processing Record 28 of Set 1 | salinopolis
# Processing Record 29 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | puerto madryn
# Processing Record 32 of Set 1 | lompoc
# Processing Record 33 of Set 1 | lavrentiya
# Processing Record 34 of Set 1 | sao filipe
# Processing Record 35 of Set 1 | cam ranh
# Processing Record 36 of Set 1 | margate
# Processing Record 37 of Set 1 | leningradskiy
# Processing Record 38 of Set 1 | saint-augustin
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | mongo
# Processing Record 41 of Set 1 | klaksvik
# Processing Record 42 of Set 1 | tura
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | denpasar
# Processing Record 45 of Set 1 | amahai
# Processing Record 46 of Set 1 | kintinku
# Processing Record 47 of Set 1 | carlsbad
# Processing Record 48 of Set 1 | kaitangata
# Processing Record 49 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 50 of Set 1 | saleilua
# City not found. Skipping...
# Processing Record 51 of Set 1 | new norfolk
# Processing Record 52 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 53 of Set 1 | provideniya
# Processing Record 54 of Set 1 | lorengau
# Processing Record 55 of Set 1 | preston
# Processing Record 56 of Set 1 | komsomolskiy
# Processing Record 57 of Set 1 | okhotsk
# Processing Record 58 of Set 1 | hilo
# Processing Record 59 of Set 1 | garden city
# Processing Record 60 of Set 1 | butaritari
# 30.8563289642334
# Processing Record 1 of Set 2 | nikolskoye
# Processing Record 2 of Set 2 | turmalina
# Processing Record 3 of Set 2 | nanma
# Processing Record 4 of Set 2 | karratha
# Processing Record 5 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 2 | airai
# Processing Record 7 of Set 2 | phuket
# Processing Record 8 of Set 2 | sao joao da barra
# Processing Record 9 of Set 2 | busselton
# Processing Record 10 of Set 2 | sokoni
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | bambanglipuro
# Processing Record 13 of Set 2 | carnarvon
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 2 | belyy yar
# Processing Record 17 of Set 2 | lata
# Processing Record 18 of Set 2 | alofi
# Processing Record 19 of Set 2 | mataura
# Processing Record 20 of Set 2 | torbay
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | fairbanks
# Processing Record 23 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 2 | karamursel
# Processing Record 25 of Set 2 | georgetown
# Processing Record 26 of Set 2 | vaini
# Processing Record 27 of Set 2 | karakendzha
# City not found. Skipping...
# Processing Record 28 of Set 2 | harigue
# City not found. Skipping...
# Processing Record 29 of Set 2 | stranraer
# Processing Record 30 of Set 2 | east london
# Processing Record 31 of Set 2 | aykhal
# Processing Record 32 of Set 2 | gao
# Processing Record 33 of Set 2 | chauk
# Processing Record 34 of Set 2 | byron bay
# Processing Record 35 of Set 2 | solenzo
# Processing Record 36 of Set 2 | mbuji-mayi
# Processing Record 37 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 2 | komyshuvakha
# Processing Record 39 of Set 2 | birao
# Processing Record 40 of Set 2 | ketchikan
# Processing Record 41 of Set 2 | raxaul
# Processing Record 42 of Set 2 | sinnamary
# Processing Record 43 of Set 2 | gorin
# Processing Record 44 of Set 2 | lebork
# Processing Record 45 of Set 2 | anta
# Processing Record 46 of Set 2 | kirovo-chepetsk
# Processing Record 47 of Set 2 | longyearbyen
# Processing Record 48 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 49 of Set 2 | bengkulu
# Processing Record 50 of Set 2 | paita
# Processing Record 51 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 52 of Set 2 | skibbereen
# Processing Record 53 of Set 2 | auki
# Processing Record 54 of Set 2 | khandyga
# Processing Record 55 of Set 2 | ludwigslust
# Processing Record 56 of Set 2 | punta arenas
# Processing Record 57 of Set 2 | prince rupert
# Processing Record 58 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 59 of Set 2 | la tuque
# Processing Record 60 of Set 2 | plettenberg bay
# 30.049246549606323
# Processing Record 1 of Set 3 | dzhalka
# Processing Record 2 of Set 3 | hobart
# Processing Record 3 of Set 3 | chokurdakh
# Processing Record 4 of Set 3 | moron
# Processing Record 5 of Set 3 | saskylakh
# Processing Record 6 of Set 3 | saldanha
# Processing Record 7 of Set 3 | khuzdar
# Processing Record 8 of Set 3 | tuatapere
# Processing Record 9 of Set 3 | bredasdorp
# Processing Record 10 of Set 3 | avarua
# Processing Record 11 of Set 3 | grindavik
# Processing Record 12 of Set 3 | turukhansk
# Processing Record 13 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 3 | bilma
# Processing Record 15 of Set 3 | iqaluit
# Processing Record 16 of Set 3 | atar
# Processing Record 17 of Set 3 | hay river
# Processing Record 18 of Set 3 | erdenet
# Processing Record 19 of Set 3 | baykit
# Processing Record 20 of Set 3 | makhachkala
# Processing Record 21 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 3 | kapaa
# Processing Record 23 of Set 3 | qurayyat
# Processing Record 24 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 3 | santa lucia
# Processing Record 26 of Set 3 | calapi
# Processing Record 27 of Set 3 | iberia
# Processing Record 28 of Set 3 | nichinan
# Processing Record 29 of Set 3 | chegem
# Processing Record 30 of Set 3 | saint anthony
# Processing Record 31 of Set 3 | campbeltown
# Processing Record 32 of Set 3 | antalaha
# Processing Record 33 of Set 3 | havoysund
# Processing Record 34 of Set 3 | katsuura
# Processing Record 35 of Set 3 | atuona
# Processing Record 36 of Set 3 | viedma
# Processing Record 37 of Set 3 | vila franca do campo
# Processing Record 38 of Set 3 | iskateley
# Processing Record 39 of Set 3 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 40 of Set 3 | maridi
# Processing Record 41 of Set 3 | henties bay
# Processing Record 42 of Set 3 | bella vista
# Processing Record 43 of Set 3 | aklavik
# Processing Record 44 of Set 3 | mitu
# Processing Record 45 of Set 3 | ust-maya
# Processing Record 46 of Set 3 | ola
# Processing Record 47 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 3 | rawson
# Processing Record 49 of Set 3 | olafsvik
# Processing Record 50 of Set 3 | mandali
# Processing Record 51 of Set 3 | dongsheng
# Processing Record 52 of Set 3 | hirara
# Processing Record 53 of Set 3 | geraldton
# Processing Record 54 of Set 3 | namibe
# Processing Record 55 of Set 3 | andenes
# Processing Record 56 of Set 3 | daru
# Processing Record 57 of Set 3 | dakar
# Processing Record 58 of Set 3 | chulumani
# Processing Record 59 of Set 3 | omboue
# Processing Record 60 of Set 3 | slidell
# 30.028021574020386
# Processing Record 1 of Set 4 | xuddur
# Processing Record 2 of Set 4 | port blair
# Processing Record 3 of Set 4 | kavaratti
# Processing Record 4 of Set 4 | cururupu
# Processing Record 5 of Set 4 | harper
# Processing Record 6 of Set 4 | pangnirtung
# Processing Record 7 of Set 4 | kassala
# Processing Record 8 of Set 4 | lashio
# Processing Record 9 of Set 4 | tuktoyaktuk
# Processing Record 10 of Set 4 | analipsis
# Processing Record 11 of Set 4 | ribeira grande
# Processing Record 12 of Set 4 | olinda
# Processing Record 13 of Set 4 | najran
# Processing Record 14 of Set 4 | melnikovo
# Processing Record 15 of Set 4 | san rafael
# Processing Record 16 of Set 4 | thompson
# Processing Record 17 of Set 4 | touros
# Processing Record 18 of Set 4 | teahupoo
# Processing Record 19 of Set 4 | los llanos de aridane
# Processing Record 20 of Set 4 | vao
# Processing Record 21 of Set 4 | esperance
# Processing Record 22 of Set 4 | sao borja
# Processing Record 23 of Set 4 | san patricio
# Processing Record 24 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 4 | mar del plata
# Processing Record 26 of Set 4 | lakatoro
# Processing Record 27 of Set 4 | narva-joesuu
# Processing Record 28 of Set 4 | tiksi
# Processing Record 29 of Set 4 | solec kujawski
# Processing Record 30 of Set 4 | kalemie
# Processing Record 31 of Set 4 | oranjemund
# Processing Record 32 of Set 4 | laguna
# Processing Record 33 of Set 4 | saint george
# Processing Record 34 of Set 4 | port elizabeth
# Processing Record 35 of Set 4 | ponta do sol
# Processing Record 36 of Set 4 | casa branca
# Processing Record 37 of Set 4 | dodola
# Processing Record 38 of Set 4 | constitucion
# Processing Record 39 of Set 4 | ahipara
# Processing Record 40 of Set 4 | ruston
# Processing Record 41 of Set 4 | gat
# Processing Record 42 of Set 4 | hasaki
# Processing Record 43 of Set 4 | port lincoln
# Processing Record 44 of Set 4 | ancud
# Processing Record 45 of Set 4 | kodiak
# Processing Record 46 of Set 4 | isangel
# Processing Record 47 of Set 4 | mandalgovi
# Processing Record 48 of Set 4 | kavieng
# Processing Record 49 of Set 4 | soe
# Processing Record 50 of Set 4 | ulladulla
# Processing Record 51 of Set 4 | bambous virieux
# Processing Record 52 of Set 4 | maragogi
# Processing Record 53 of Set 4 | roma
# Processing Record 54 of Set 4 | natal
# Processing Record 55 of Set 4 | odweyne
# Processing Record 56 of Set 4 | labuhan
# Processing Record 57 of Set 4 | north bend
# Processing Record 58 of Set 4 | sola
# Processing Record 59 of Set 4 | mount gambier
# Processing Record 60 of Set 4 | nishihara
# 29.758861780166626
# Processing Record 1 of Set 5 | ostrovnoy
# Processing Record 2 of Set 5 | la rioja
# Processing Record 3 of Set 5 | lebu
# Processing Record 4 of Set 5 | eganville
# Processing Record 5 of Set 5 | pyay
# Processing Record 6 of Set 5 | taltal
# Processing Record 7 of Set 5 | mangaratiba
# Processing Record 8 of Set 5 | krasnyy chikoy
# Processing Record 9 of Set 5 | cabadiangan
# Processing Record 10 of Set 5 | uglovskoye
# Processing Record 11 of Set 5 | panvel
# Processing Record 12 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 13 of Set 5 | lardos
# Processing Record 14 of Set 5 | shingu
# Processing Record 15 of Set 5 | galesong
# Processing Record 16 of Set 5 | frontino
# Processing Record 17 of Set 5 | yumen
# Processing Record 18 of Set 5 | sobolevo
# Processing Record 19 of Set 5 | jasper
# Processing Record 20 of Set 5 | mangrol
# Processing Record 21 of Set 5 | biryusinsk
# Processing Record 22 of Set 5 | tautira
# Processing Record 23 of Set 5 | souillac
# Processing Record 24 of Set 5 | taganak
# Processing Record 25 of Set 5 | whyalla
# Processing Record 26 of Set 5 | lavumisa
# Processing Record 27 of Set 5 | cockburn town
# Processing Record 28 of Set 5 | khatanga
# Processing Record 29 of Set 5 | victoria
# Processing Record 30 of Set 5 | inhambane
# Processing Record 31 of Set 5 | wajima
# Processing Record 32 of Set 5 | altay
# Processing Record 33 of Set 5 | kieta
# Processing Record 34 of Set 5 | srednekolymsk
# Processing Record 35 of Set 5 | xining
# Processing Record 36 of Set 5 | mitsamiouli
# Processing Record 37 of Set 5 | tasiilaq
# Processing Record 38 of Set 5 | yar-sale
# Processing Record 39 of Set 5 | vilyuysk
# Processing Record 40 of Set 5 | castro
# Processing Record 41 of Set 5 | cidreira
# Processing Record 42 of Set 5 | moree
# Processing Record 43 of Set 5 | mahebourg
# Processing Record 44 of Set 5 | kupang
# Processing Record 45 of Set 5 | rajpipla
# Processing Record 46 of Set 5 | portland
# Processing Record 47 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 5 | rayevskiy
# Processing Record 49 of Set 5 | lalibela
# Processing Record 50 of Set 5 | haines junction
# Processing Record 51 of Set 5 | ascension
# Processing Record 52 of Set 5 | orotukan
# Processing Record 53 of Set 5 | lixourion
# Processing Record 54 of Set 5 | anloga
# Processing Record 55 of Set 5 | hervey bay
# Processing Record 56 of Set 5 | lagoa
# Processing Record 57 of Set 5 | port keats
# Processing Record 58 of Set 5 | tabuk
# Processing Record 59 of Set 5 | abu dhabi
# Processing Record 60 of Set 5 | quang ngai
# 30.414119720458984
# Processing Record 1 of Set 6 | cucer
# City not found. Skipping...
# Processing Record 2 of Set 6 | yaring
# Processing Record 3 of Set 6 | andrews
# Processing Record 4 of Set 6 | sarishabari
# Processing Record 5 of Set 6 | kungurtug
# Processing Record 6 of Set 6 | bereznehuvate
# Processing Record 7 of Set 6 | america dourada
# Processing Record 8 of Set 6 | dingle
# Processing Record 9 of Set 6 | la primavera
# Processing Record 10 of Set 6 | gravdal
# Processing Record 11 of Set 6 | baracoa
# Processing Record 12 of Set 6 | okany
# Processing Record 13 of Set 6 | edinburg
# Processing Record 14 of Set 6 | pokhara
# Processing Record 15 of Set 6 | tilichiki
# Processing Record 16 of Set 6 | cherskiy
# Processing Record 17 of Set 6 | port hawkesbury
# Processing Record 18 of Set 6 | bhadrachalam
# Processing Record 19 of Set 6 | pisco
# Processing Record 20 of Set 6 | sorland
# Processing Record 21 of Set 6 | savannah bight
# Processing Record 22 of Set 6 | bud
# Processing Record 23 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 6 | kaseda
# Processing Record 25 of Set 6 | dunedin
# Processing Record 26 of Set 6 | bethel
# Processing Record 27 of Set 6 | ajdabiya
# Processing Record 28 of Set 6 | zemio
# Processing Record 29 of Set 6 | altamont
# Processing Record 30 of Set 6 | kruisfontein
# Processing Record 31 of Set 6 | talnakh
# Processing Record 32 of Set 6 | intipuca
# Processing Record 33 of Set 6 | palm coast
# Processing Record 34 of Set 6 | batesville
# Processing Record 35 of Set 6 | gamba
# Processing Record 36 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 37 of Set 6 | abha
# Processing Record 38 of Set 6 | vidisha
# Processing Record 39 of Set 6 | rehnan
# Processing Record 40 of Set 6 | tual
# Processing Record 41 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 6 | nouadhibou
# Processing Record 43 of Set 6 | vila velha
# Processing Record 44 of Set 6 | entre rios
# Processing Record 45 of Set 6 | sabang
# Processing Record 46 of Set 6 | flinders
# Processing Record 47 of Set 6 | castlegar
# Processing Record 48 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 6 | beringovskiy
# Processing Record 50 of Set 6 | jiancheng
# Processing Record 51 of Set 6 | waldkraiburg
# Processing Record 52 of Set 6 | berlevag
# Processing Record 53 of Set 6 | port hedland
# Processing Record 54 of Set 6 | lasa
# Processing Record 55 of Set 6 | mildura
# Processing Record 56 of Set 6 | chimoio
# Processing Record 57 of Set 6 | katherine
# Processing Record 58 of Set 6 | lunavada
# Processing Record 59 of Set 6 | kudahuvadhoo
# Processing Record 60 of Set 6 | kautokeino
# 30.242785692214966
# Processing Record 1 of Set 7 | zhigansk
# Processing Record 2 of Set 7 | toufen
# Processing Record 3 of Set 7 | kihei
# Processing Record 4 of Set 7 | khao wong
# Processing Record 5 of Set 7 | dibaya
# City not found. Skipping...
# Processing Record 6 of Set 7 | kawana waters
# City not found. Skipping...
# Processing Record 7 of Set 7 | tateyama
# Processing Record 8 of Set 7 | galgani
# City not found. Skipping...
# Processing Record 9 of Set 7 | san pedro
# Processing Record 10 of Set 7 | san isidro
# Processing Record 11 of Set 7 | mozarlandia
# Processing Record 12 of Set 7 | salym
# Processing Record 13 of Set 7 | marzuq
# Processing Record 14 of Set 7 | puerto guzman
# Processing Record 15 of Set 7 | kloulklubed
# Processing Record 16 of Set 7 | miri
# Processing Record 17 of Set 7 | petatlan
# Processing Record 18 of Set 7 | caxito
# Processing Record 19 of Set 7 | hofn
# Processing Record 20 of Set 7 | marabba
# Processing Record 21 of Set 7 | oistins
# Processing Record 22 of Set 7 | kokopo
# Processing Record 23 of Set 7 | hamilton
# Processing Record 24 of Set 7 | teguldet
# Processing Record 25 of Set 7 | kuching
# Processing Record 26 of Set 7 | shimoda
# Processing Record 27 of Set 7 | saint-georges
# Processing Record 28 of Set 7 | clearwater
# Processing Record 29 of Set 7 | empalme
# Processing Record 30 of Set 7 | ksenyevka
# City not found. Skipping...
# Processing Record 31 of Set 7 | qaqortoq
# Processing Record 32 of Set 7 | labrea
# Processing Record 33 of Set 7 | meadow lake
# Processing Record 34 of Set 7 | udachnyy
# Processing Record 35 of Set 7 | marawi
# Processing Record 36 of Set 7 | juifang
# City not found. Skipping...
# Processing Record 37 of Set 7 | ingleside
# Processing Record 38 of Set 7 | kamenka
# Processing Record 39 of Set 7 | cap malheureux
# Processing Record 40 of Set 7 | dukat
# Processing Record 41 of Set 7 | karasjok
# Processing Record 42 of Set 7 | isabela
# Processing Record 43 of Set 7 | nome
# Processing Record 44 of Set 7 | houma
# Processing Record 45 of Set 7 | jalu
# Processing Record 46 of Set 7 | yeppoon
# Processing Record 47 of Set 7 | rafai
# Processing Record 48 of Set 7 | kitakata
# Processing Record 49 of Set 7 | bengkalis
# City not found. Skipping...
# Processing Record 50 of Set 7 | la asuncion
# Processing Record 51 of Set 7 | sitka
# Processing Record 52 of Set 7 | brae
# Processing Record 53 of Set 7 | upington
# Processing Record 54 of Set 7 | pak phanang
# Processing Record 55 of Set 7 | khani
# Processing Record 56 of Set 7 | semey
# Processing Record 57 of Set 7 | muisne
# Processing Record 58 of Set 7 | senneterre
# Processing Record 59 of Set 7 | syracuse
# Processing Record 60 of Set 7 | springdale
# 29.78827977180481
# Processing Record 1 of Set 8 | srandakan
# Processing Record 2 of Set 8 | katangli
# Processing Record 3 of Set 8 | karibib
# Processing Record 4 of Set 8 | cabo san lucas
# Processing Record 5 of Set 8 | creel
# Processing Record 6 of Set 8 | saiha
# Processing Record 7 of Set 8 | mukhen
# Processing Record 8 of Set 8 | sorong
# Processing Record 9 of Set 8 | muzhi
# Processing Record 10 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 8 | inta
# Processing Record 12 of Set 8 | yomou
# Processing Record 13 of Set 8 | harlingen
# Processing Record 14 of Set 8 | fort nelson
# Processing Record 15 of Set 8 | nanortalik
# Processing Record 16 of Set 8 | teguise
# Processing Record 17 of Set 8 | custoias
# Processing Record 18 of Set 8 | waipawa
# Processing Record 19 of Set 8 | chupa
# Processing Record 20 of Set 8 | akureyri
# Processing Record 21 of Set 8 | huoqiu
# Processing Record 22 of Set 8 | high level
# Processing Record 23 of Set 8 | acolla
# Processing Record 24 of Set 8 | port-gentil
# Processing Record 25 of Set 8 | karoi
# Processing Record 26 of Set 8 | te anau
# Processing Record 27 of Set 8 | kiruna
# Processing Record 28 of Set 8 | westport
# Processing Record 29 of Set 8 | turangi
# Processing Record 30 of Set 8 | alice springs
# Processing Record 31 of Set 8 | bandarbeyla
# Processing Record 32 of Set 8 | umm lajj
# Processing Record 33 of Set 8 | cabedelo
# Processing Record 34 of Set 8 | caravelas
# Processing Record 35 of Set 8 | kysyl-syr
# Processing Record 36 of Set 8 | tiznit
# Processing Record 37 of Set 8 | thinadhoo
# Processing Record 38 of Set 8 | kiunga
# Processing Record 39 of Set 8 | srivardhan
# Processing Record 40 of Set 8 | baherden
# Processing Record 41 of Set 8 | sakakah
# Processing Record 42 of Set 8 | takoradi
# Processing Record 43 of Set 8 | nicoya
# Processing Record 44 of Set 8 | conakry
# Processing Record 45 of Set 8 | bathsheba
# Processing Record 46 of Set 8 | bubaque
# Processing Record 47 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 8 | bulgan
# Processing Record 49 of Set 8 | goderich
# Processing Record 50 of Set 8 | dudinka
# Processing Record 51 of Set 8 | roebourne
# Processing Record 52 of Set 8 | bose
# Processing Record 53 of Set 8 | longyan
# Processing Record 54 of Set 8 | husavik
# Processing Record 55 of Set 8 | lahat
# Processing Record 56 of Set 8 | batagay-alyta
# Processing Record 57 of Set 8 | half moon bay
# Processing Record 58 of Set 8 | mahibadhoo
# Processing Record 59 of Set 8 | little current
# Processing Record 60 of Set 8 | batemans bay
# 30.13483238220215
# Processing Record 1 of Set 9 | cerrito
# Processing Record 2 of Set 9 | itarema
# Processing Record 3 of Set 9 | dzidzantun
# Processing Record 4 of Set 9 | salalah
# Processing Record 5 of Set 9 | nelson bay
# Processing Record 6 of Set 9 | bongandanga
# Processing Record 7 of Set 9 | salisbury
# Processing Record 8 of Set 9 | xinmin
# Processing Record 9 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 9 | mao
# Processing Record 11 of Set 9 | emporia
# Processing Record 12 of Set 9 | clyde river
# Processing Record 13 of Set 9 | koshurnikovo
# Processing Record 14 of Set 9 | beloha
# Processing Record 15 of Set 9 | codrington
# Processing Record 16 of Set 9 | mersing
# Processing Record 17 of Set 9 | vardo
# Processing Record 18 of Set 9 | ormara
# Processing Record 19 of Set 9 | murgab
# Processing Record 20 of Set 9 | walvis bay
# Processing Record 21 of Set 9 | rio grande
# Processing Record 22 of Set 9 | kefamenanu
# Processing Record 23 of Set 9 | sun valley
# Processing Record 24 of Set 9 | yeletskiy
# City not found. Skipping...
# Processing Record 25 of Set 9 | linxia
# Processing Record 26 of Set 9 | kidal
# Processing Record 27 of Set 9 | arlit
# Processing Record 28 of Set 9 | yuanping
# Processing Record 29 of Set 9 | bairiki
# Processing Record 30 of Set 9 | wuwei
# Processing Record 31 of Set 9 | palmer
# Processing Record 32 of Set 9 | malaya serdoba
# Processing Record 33 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 9 | east wenatchee bench
# Processing Record 35 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 36 of Set 9 | novoagansk
# Processing Record 37 of Set 9 | jinchang
# Processing Record 38 of Set 9 | gornopravdinsk
# Processing Record 39 of Set 9 | key west
# Processing Record 40 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 41 of Set 9 | coihaique
# Processing Record 42 of Set 9 | baloda
# Processing Record 43 of Set 9 | batagay
# Processing Record 44 of Set 9 | surt
# Processing Record 45 of Set 9 | parrita
# Processing Record 46 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 9 | narsaq
# Processing Record 48 of Set 9 | buraydah
# Processing Record 49 of Set 9 | the valley
# Processing Record 50 of Set 9 | humberto de campos
# Processing Record 51 of Set 9 | santa cruz
# Processing Record 52 of Set 9 | nakatsu
# Processing Record 53 of Set 9 | mocuba
# Processing Record 54 of Set 9 | ilhabela
# Processing Record 55 of Set 9 | remontnoye
# Processing Record 56 of Set 9 | kushima
# Processing Record 57 of Set 9 | yurga
# Processing Record 58 of Set 9 | azua
# Processing Record 59 of Set 9 | richards bay
# Processing Record 60 of Set 9 | paveh
# 30.00972843170166
# Processing Record 1 of Set 10 | karamay
# City not found. Skipping...
# Processing Record 2 of Set 10 | akyab
# Processing Record 3 of Set 10 | jilib
# Processing Record 4 of Set 10 | fortuna
# Processing Record 5 of Set 10 | pandan
# Processing Record 6 of Set 10 | kushnarenkovo
# Processing Record 7 of Set 10 | noumea
# Processing Record 8 of Set 10 | linden
# Processing Record 9 of Set 10 | kytlym
# City not found. Skipping...
# Processing Record 10 of Set 10 | pakxe
# Processing Record 11 of Set 10 | bonthe
# Processing Record 12 of Set 10 | ardrishaig
# Processing Record 13 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 14 of Set 10 | iquique
# Processing Record 15 of Set 10 | yerbogachen
# Processing Record 16 of Set 10 | chicama
# Processing Record 17 of Set 10 | mitzic
# Processing Record 18 of Set 10 | banning
# Processing Record 19 of Set 10 | dianopolis
# City not found. Skipping...
# Processing Record 20 of Set 10 | medea
# Processing Record 21 of Set 10 | fergus falls
# Processing Record 22 of Set 10 | bileca
# Processing Record 23 of Set 10 | tinjah
# City not found. Skipping...
# Processing Record 24 of Set 10 | galveston
# Processing Record 25 of Set 10 | narasannapeta
# Processing Record 26 of Set 10 | port macquarie
# Processing Record 27 of Set 10 | sainte-anne-des-monts
# Processing Record 28 of Set 10 | troitsko-pechorsk
# Processing Record 29 of Set 10 | thornhill
# Processing Record 30 of Set 10 | tucuman
# Processing Record 31 of Set 10 | mbandaka
# Processing Record 32 of Set 10 | le creusot
# Processing Record 33 of Set 10 | yulara
# Processing Record 34 of Set 10 | awjilah
# Processing Record 35 of Set 10 | ilulissat
# Processing Record 36 of Set 10 | bay roberts
# Processing Record 37 of Set 10 | ler
# Processing Record 38 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 39 of Set 10 | ambon
# Processing Record 40 of Set 10 | san quintin
# Processing Record 41 of Set 10 | hovd
# Processing Record 42 of Set 10 | burg
# Processing Record 43 of Set 10 | boa vista
# Processing Record 44 of Set 10 | yenagoa
# Processing Record 45 of Set 10 | rucheng
# Processing Record 46 of Set 10 | bonavista
# Processing Record 47 of Set 10 | lumeje
# Processing Record 48 of Set 10 | yekepa
# Processing Record 49 of Set 10 | abu jubayhah
# City not found. Skipping...
# Processing Record 50 of Set 10 | kyra
# Processing Record 51 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 52 of Set 10 | kondinskoye
# Processing Record 53 of Set 10 | sibolga
# Processing Record 54 of Set 10 | bereda
# Processing Record 55 of Set 10 | koryukivka
# Processing Record 56 of Set 10 | urusha
# Processing Record 57 of Set 10 | pithoro
# Processing Record 58 of Set 10 | tullow
# Processing Record 59 of Set 10 | guerrero negro
# Processing Record 60 of Set 10 | totness
# 30.264184713363647
# Processing Record 1 of Set 11 | matagami
# Processing Record 2 of Set 11 | vanderhoof
# Processing Record 3 of Set 11 | mananjary
# Processing Record 4 of Set 11 | lufilufi
# Processing Record 5 of Set 11 | halifax
# Processing Record 6 of Set 11 | lethem
# Processing Record 7 of Set 11 | mackenzie
# Processing Record 8 of Set 11 | trairi
# Processing Record 9 of Set 11 | piet retief
# Processing Record 10 of Set 11 | pavilosta
# Processing Record 11 of Set 11 | brandon
# Processing Record 12 of Set 11 | pangkalanbuun
# Processing Record 13 of Set 11 | acajutla
# Processing Record 14 of Set 11 | mumford
# Processing Record 15 of Set 11 | santiago
# Processing Record 16 of Set 11 | trofors
# Processing Record 17 of Set 11 | sur
# Processing Record 18 of Set 11 | berekum
# Processing Record 19 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 11 | kerteh
# City not found. Skipping...
# Processing Record 21 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 11 | poum
# Processing Record 23 of Set 11 | belmonte
# Processing Record 24 of Set 11 | saijo
# Processing Record 25 of Set 11 | la libertad
# Processing Record 26 of Set 11 | keti bandar
# Processing Record 27 of Set 11 | naze
# Processing Record 28 of Set 11 | roald
# Processing Record 29 of Set 11 | nyurba
# Processing Record 30 of Set 11 | makubetsu
# Processing Record 31 of Set 11 | kaeo
# Processing Record 32 of Set 11 | dvinskoy
# Processing Record 33 of Set 11 | egvekinot
# Processing Record 34 of Set 11 | aljezur
# Processing Record 35 of Set 11 | puerto escondido
# Processing Record 36 of Set 11 | novikovo
# Processing Record 37 of Set 11 | adrar
# Processing Record 38 of Set 11 | mitrofanovka
# Processing Record 39 of Set 11 | avera
# Processing Record 40 of Set 11 | muros
# Processing Record 41 of Set 11 | williams lake
# Processing Record 42 of Set 11 | marsh harbour
# Processing Record 43 of Set 11 | sept-iles
# Processing Record 44 of Set 11 | hurricane
# Processing Record 45 of Set 11 | mehamn
# Processing Record 46 of Set 11 | filingue
# Processing Record 47 of Set 11 | college
# Processing Record 48 of Set 11 | masvingo
# Processing Record 49 of Set 11 | kurumkan
# Processing Record 50 of Set 11 | toora-khem
# Processing Record 51 of Set 11 | karaton
# Processing Record 52 of Set 11 | alyangula
# Processing Record 53 of Set 11 | hamadan
# Processing Record 54 of Set 11 | tahoua
# Processing Record 55 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 56 of Set 11 | matara
# Processing Record 57 of Set 11 | rome
# Processing Record 58 of Set 11 | zabol
# Processing Record 59 of Set 11 | trelew
# Processing Record 60 of Set 11 | mizan teferi
# 29.952499628067017
# Processing Record 1 of Set 12 | coquimbo
# Processing Record 2 of Set 12 | shitanjing
# Processing Record 3 of Set 12 | hargeysa
# Processing Record 4 of Set 12 | namatanai
# Processing Record 5 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 6 of Set 12 | jinan
# Processing Record 7 of Set 12 | ouadda
# Processing Record 8 of Set 12 | diapaga
# Processing Record 9 of Set 12 | bukachacha
# Processing Record 10 of Set 12 | nioro
# Processing Record 11 of Set 12 | filadelfia
# Processing Record 12 of Set 12 | razdolnoye
# Processing Record 13 of Set 12 | menongue
# Processing Record 14 of Set 12 | gashua
# Processing Record 15 of Set 12 | moose factory
# Processing Record 16 of Set 12 | siloam springs
# Processing Record 17 of Set 12 | tooele
# Processing Record 18 of Set 12 | parthenay
# Processing Record 19 of Set 12 | skjervoy
# Processing Record 20 of Set 12 | ipixuna
# Processing Record 21 of Set 12 | yermakovskoye
# Processing Record 22 of Set 12 | isiro
# Processing Record 23 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 12 | tibiri
# Processing Record 25 of Set 12 | mikuni
# Processing Record 26 of Set 12 | crossville
# Processing Record 27 of Set 12 | le port
# Processing Record 28 of Set 12 | wamba
# Processing Record 29 of Set 12 | aswan
# Processing Record 30 of Set 12 | ixtapa
# Processing Record 31 of Set 12 | santa isabel do rio negro
# Processing Record 32 of Set 12 | kampene
# Processing Record 33 of Set 12 | eureka
# Processing Record 34 of Set 12 | hue
# Processing Record 35 of Set 12 | zarasai
# Processing Record 36 of Set 12 | alugan
# Processing Record 37 of Set 12 | mamallapuram
# Processing Record 38 of Set 12 | maputo
# Processing Record 39 of Set 12 | muli
# Processing Record 40 of Set 12 | graaff-reinet
# Processing Record 41 of Set 12 | lewistown
# Processing Record 42 of Set 12 | neyshabur
# Processing Record 43 of Set 12 | bonaventure
# Processing Record 44 of Set 12 | teya
# Processing Record 45 of Set 12 | songjianghe
# Processing Record 46 of Set 12 | jining
# Processing Record 47 of Set 12 | sakata
# Processing Record 48 of Set 12 | camana
# Processing Record 49 of Set 12 | povenets
# Processing Record 50 of Set 12 | hualmay
# Processing Record 51 of Set 12 | melo
# Processing Record 52 of Set 12 | ungheni
# Processing Record 53 of Set 12 | oron
# Processing Record 54 of Set 12 | yichang
# Processing Record 55 of Set 12 | montclair
# Processing Record 56 of Set 12 | hobyo
# Processing Record 57 of Set 12 | oktyabrskoye
# Processing Record 58 of Set 12 | bogen
# Processing Record 59 of Set 12 | ulcinj
# Processing Record 60 of Set 12 | mahon
# 29.671103954315186
# Processing Record 1 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 2 of Set 13 | sabha
# Processing Record 3 of Set 13 | samarai
# Processing Record 4 of Set 13 | vuktyl
# Processing Record 5 of Set 13 | pierre
# ---------------------------------
# Data Retrieval Complete
# ---------------------------------

# %%
# Create the DataFrame from the dictionary
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Pevek  69.7008  170.3133    -30.62        99          65
# 1         Jamestown  42.0970  -79.2353     36.72        94          90
# 2              Faya  18.3851   42.4509     59.52        71           2
# 3      Norman Wells  65.2820 -126.8329     -2.16        78          90
# 4    Saint-Philippe -21.3585   55.7679     74.79        83          89
# ..              ...      ...       ...       ...       ...         ...
# 665           Mahon  39.8885    4.2658     57.76        82           0
# 666           Sabha  27.0377   14.4283     56.19        30           2
# 667         Samarai -10.6167  150.6667     81.81        78         100
# 668          Vuktyl  63.8567   57.3094      4.46        95         100
# 669          Pierre  44.3683 -100.3510     13.12        57           1
#
#      Wind Speed Country Current Description
# 0          4.76      RU       broken clouds
# 1          3.00      US                mist
# 2          1.72      SA           clear sky
# 3          0.00      CA          light snow
# 4          8.63      RE     overcast clouds
# ..          ...     ...                 ...
# 665        6.91      ES           clear sky
# 666        3.49      LY           clear sky
# 667        4.25      PG     overcast clouds
# 668        6.44      RU     overcast clouds
# 669        6.91      US           clear sky
#
# [670 rows x 9 columns]

# %%
# Reorder the DataFrame columns
city_data_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']]
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Pevek      RU  69.7008  170.3133    -30.62        99          65
# 1       Jamestown      US  42.0970  -79.2353     36.72        94          90
# 2            Faya      SA  18.3851   42.4509     59.52        71           2
# 3    Norman Wells      CA  65.2820 -126.8329     -2.16        78          90
# 4  Saint-Philippe      RE -21.3585   55.7679     74.79        83          89
#
#    Wind Speed Current Description
# 0        4.76       broken clouds
# 1        3.00                mist
# 2        1.72           clear sky
# 3        0.00          light snow
# 4        8.63     overcast clouds

# %%
# Create the output file (CSV)
output_data_file = "../weather_database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
#city_data_df.to_csv(output_data_file, index_label="City")
city_data_df.to_csv(output_data_file, header=True, index=False)
